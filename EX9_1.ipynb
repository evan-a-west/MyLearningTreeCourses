# %% [markdown]
# # Hands-On Exercise 9.1:
# # Creating & Visualizing Social Networks
# ***

# %% [markdown]
# ## Objectives
#
# #### In this exercise, you will examine network data and graph object attributes. This exercise allows you to define objects and relationships as nodes and edges in a graph object. The goal is to show you how real-world relationships can be represented in data as well as how they can be plotted to uncover patterns through visualization.
#
# ### Overview
#
# In this exercise you will:<br>
# •	Create and plot graphs<br>
# •	Work with graph attributes<br>
# •	Use plotting parameters to uncover patterns<br><br>
#
# **Pre-step: Execute the following cell in order to suppress warning messages**

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# 1. ❏ Import the **networkx** package

# %%
import networkx as nx

# %% [markdown]
# 2. ❏ Create this graph using the **add_edge()** function
# ![image.png](attachment:image.png)

# %%
G_group = nx.Graph()

G_group.add_edge('Win','Régine')
G_group.add_edge('Win','William')
G_group.add_edge('Win','Richard')
G_group.add_edge('Win','Tim')
G_group.add_edge('Régine','William')
G_group.add_edge('Régine','Richard')
G_group.add_edge('Régine','Tim')
G_group.add_edge('Régine','Jeremy')

# %% [markdown]
# 3. ❏ Draw the graph

# %%
nx.draw_networkx(G_group)

# %% [markdown]
# 4. ❏ Using the **.add_edges_from()** method on a graph, create a list of edges between nodes with the following names:<br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Donald<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Francois<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Vladimir<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Kim<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Justin<br><br>
# and draw the resulting graph<br><br>
# *Hint: The connections between the nodes can be of your own choosing*

# %%
G_names = nx.Graph()
G_names.add_edges_from([("Donald", "Francois"), ("Donald", "Vladimir"), ("Donald", "Kin"), ("Donald", "Justin")])
nx.draw_networkx(G_names)

# %% [markdown]
# 5. ❏ Give the graph an attribute **Title** with a value of **Presidents**

# %%
G_names.graph["Title"] = "Presidents"
G_names.graph["Title"]
# Out:
# 'Presidents'

# %% [markdown]
# 6. ❏ View attribute information on the graph

# %%
G_names.graph
# Out:
# {'Title': 'Presidents'}

# %% [markdown]
# 7. ❏  Import the links/edges stored in the file **SNADataset1_links.csv** using the **read_edgelist()** function and draw it

# %%
G1 = nx.read_edgelist("SNADataset1_links.csv", delimiter=',', create_using=nx.Graph(), nodetype=str, data=[('type', str),('weight', float)])
nx.draw_networkx(G1)

# %% [markdown]
# 8. ❏ Import the **pandas** package and import the file **SNADataset1_nodes.csv** into  a dataframe

# %%
import pandas as pd
df = pd.read_csv("SNADataset1_nodes.csv", index_col=0)
df
# Out:
#                    media  media.type type.label  audience.size
# id
# s01             NY Times           1  Newspaper             20
# s02      Washington Post           1  Newspaper             25
# s03  Wall Street Journal           1  Newspaper             30
# s04            USA Today           1  Newspaper             32
# s05             LA Times           1  Newspaper             20
# s06        New York Post           1  Newspaper             50
# s07                  CNN           2         TV             56
# s08                MSNBC           2         TV             34
# s09             FOX News           2         TV             60
# s10                  ABC           2         TV             23
# s11                  BBC           2         TV             34
# s12           Yahoo News           3     Online             33
# s13          Google News           3     Online             23
# s14          Reuters.com           3     Online             12
# s15          NYTimes.com           3     Online             24
# s16   WashingtonPost.com           3     Online             28
# s17              AOL.com           3     Online             33

# %% [markdown]
# 9. ❏ Assign the data from the imported dataset as node attributes on the graph that you have created using the **.set_node_attributes()** function

# %%
nx.set_node_attributes(G1, df.to_dict('index'))

# %% [markdown]
# 10. ❏ View the node attribute data

# %%
G1.nodes(data=True)
# Out:
# NodeDataView({'s01': {'media': 'NY Times', 'media.type': 1, 'type.label': 'Newspaper', 'audience.size': 20}, 's02': {'media': 'Washington Post', 'media.type': 1, 'type.label': 'Newspaper', 'audience.size': 25}, 's03': {'media': 'Wall Street Journal', 'media.type': 1, 'type.label': 'Newspaper', 'audience.size': 30}, 's04': {'media': 'USA Today', 'media.type': 1, 'type.label': 'Newspaper', 'audience.size': 32}, 's15': {'media': 'NYTimes.com', 'media.type': 3, 'type.label': 'Online', 'audience.size': 24}, 's09': {'media': 'FOX News', 'media.type': 2, 'type.label': 'TV', 'audience.size': 60}, 's10': {'media': 'ABC', 'media.type': 2, 'type.label': 'TV', 'audience.size': 23}, 's05': {'media': 'LA Times', 'media.type': 1, 'type.label': 'Newspaper', 'audience.size': 20}, 's08': {'media': 'MSNBC', 'media.type': 2, 'type.label': 'TV', 'audience.size': 34}, 's11': {'media': 'BBC', 'media.type': 2, 'type.label': 'TV', 'audience.size': 34}, 's12': {'media': 'Yahoo News', 'media.type': 3, 'type.label': 'Online', 'audience.size': 33}, 's06': {'media': 'New York Post', 'media.type': 1, 'type.label': 'Newspaper', 'audience.size': 50}, 's17': {'media': 'AOL.com', 'media.type': 3, 'type.label': 'Online', 'audience.size': 33}, 's16': {'media': 'WashingtonPost.com', 'media.type': 3, 'type.label': 'Online', 'audience.size': 28}, 's07': {'media': 'CNN', 'media.type': 2, 'type.label': 'TV', 'audience.size': 56}, 's14': {'media': 'Reuters.com', 'media.type': 3, 'type.label': 'Online', 'audience.size': 12}, 's13': {'media': 'Google News', 'media.type': 3, 'type.label': 'Online', 'audience.size': 23}})

# %% [markdown]
# 11. ❏ View the edge attribute data from the graph you have created

# %%
G1.edges(data=True)
# Out:
# EdgeDataView([('s01', 's02', {'type': 'hyperlink', 'weight': 23.0}), ('s01', 's03', {'type': 'hyperlink', 'weight': 21.0}), ('s01', 's04', {'type': 'hyperlink', 'weight': 21.0}), ('s01', 's15', {'type': 'hyperlink', 'weight': 22.0}), ('s01', 's05', {'type': 'mention', 'weight': 1.0}), ('s02', 's03', {'type': 'hyperlink', 'weight': 21.0}), ('s02', 's09', {'type': 'hyperlink', 'weight': 1.0}), ('s02', 's10', {'type': 'hyperlink', 'weight': 5.0}), ('s02', 's05', {'type': 'hyperlink', 'weight': 21.0}), ('s03', 's04', {'type': 'hyperlink', 'weight': 23.0}), ('s03', 's05', {'type': 'hyperlink', 'weight': 1.0}), ('s03', 's08', {'type': 'hyperlink', 'weight': 2.0}), ('s03', 's10', {'type': 'hyperlink', 'weight': 2.0}), ('s03', 's11', {'type': 'hyperlink', 'weight': 1.0}), ('s03', 's12', {'type': 'hyperlink', 'weight': 1.0}), ('s03', 's07', {'type': 'mention', 'weight': 1.0}), ('s04', 's06', {'type': 'mention', 'weight': 1.0}), ('s04', 's11', {'type': 'mention', 'weight': 22.0}), ('s04', 's12', {'type': 'hyperlink', 'weight': 3.0}), ('s04', 's17', {'type': 'hyperlink', 'weight': 4.0}), ('s04', 's15', {'type': 'hyperlink', 'weight': 1.0}), ('s15', 's05', {'type': 'mention', 'weight': 21.0}), ('s15', 's06', {'type': 'hyperlink', 'weight': 4.0}), ('s09', 's05', {'type': 'hyperlink', 'weight': 2.0}), ('s09', 's08', {'type': 'mention', 'weight': 23.0}), ('s09', 's10', {'type': 'mention', 'weight': 21.0}), ('s10', 's07', {'type': 'hyperlink', 'weight': 21.0}), ('s08', 's07', {'type': 'mention', 'weight': 21.0}), ('s11', 's14', {'type': 'mention', 'weight': 1.0}), ('s12', 's06', {'type': 'mention', 'weight': 2.0}), ('s12', 's13', {'type': 'hyperlink', 'weight': 21.0}), ('s12', 's14', {'type': 'mention', 'weight': 22.0}), ('s06', 's06', {'type': 'hyperlink', 'weight': 1.0}), ('s06', 's16', {'type': 'hyperlink', 'weight': 23.0}), ('s06', 's17', {'type': 'mention', 'weight': 21.0}), ('s17', 's13', {'type': 'mention', 'weight': 1.0}), ('s17', 's16', {'type': 'mention', 'weight': 21.0}), ('s07', 's14', {'type': 'mention', 'weight': 4.0}), ('s14', 's13', {'type': 'mention', 'weight': 21.0})])

# %% [markdown]
# 12. ❏ View the 3 media types in the graph using the **get_node_attributes()** function and the attribute **media.type**

# %%
nx.get_node_attributes(G1, "media.type")
# Out:
# {'s01': 1,
#  's02': 1,
#  's03': 1,
#  's04': 1,
#  's15': 3,
#  's09': 2,
#  's10': 2,
#  's05': 1,
#  's08': 2,
#  's11': 2,
#  's12': 3,
#  's06': 1,
#  's17': 3,
#  's16': 3,
#  's07': 2,
#  's14': 3,
#  's13': 3}

# %% [markdown]
# 13. ❏ Draw graph *G_group* (created in step 2) with square shaped nodes and colored skyblue

# %%
nx.draw(G_group, with_labels=True, node_color='skyblue', node_shape='s')

# %% [markdown]
# 14. ❏ Size the nodes on the graph according to their audience size

# %%
node_size = []
for node in G1.nodes:
    node_size.append(G1.nodes[node]['audience.size']**2)
node_labels = nx.get_node_attributes(G1, 'media')
nx.draw(G1, node_size=node_size, labels=node_labels)

# %% [markdown]
# 15. ❏ Cdolor the nodes on the G_media graph according to their media type

# %%
node_color = []
for node in G1.nodes:
    if G1.nodes[node]['media.type']==1:
        node_color.append('blue')
    elif G1.nodes[node]['media.type']==2:
        node_color.append('green')
    else:
        node_color.append('red')

nx.draw(G1, node_size=node_size, labels=node_labels, node_color=node_color)

# %% [markdown]
# 16. ❏ Increase the width of the lines on the graph according to their edge_weight

# %%
edge_weight = []
for edge in G1.edges:
    edge_weight.append(G1.edges[edge]['weight']/3)
nx.draw(G1, node_size=node_size, labels=node_labels, node_color=node_color, width=edge_weight)

# %% [markdown]
# 17. ❏  Draw graph G_group with the following 5 layouts:<br>
# •	Fruchterman Reingold<br>
# •	Circular<br>
# •	Random<br>
# •	Spectral<br>
# •	Spring<br>

# %%
nx.draw(G_group, with_labels=True, node_size=1500, node_color='skyblue',pos=nx.fruchterman_reingold_layout(G_group))

# %%
nx.draw(G_group, with_labels=True, node_size=1500, node_color='skyblue', pos=nx.circular_layout(G_group))

# %%
nx.draw(G_group, with_labels=True, node_size=1500, node_color='skyblue', pos=nx.random_layout(G_group))

# %%
nx.draw(G_group, with_labels=True, node_size=1500, node_color='skyblue', pos=nx.spectral_layout(G_group))

# %%
nx.draw(G_group, with_labels=True, node_size=1500, node_color='skyblue', pos=nx.spring_layout(G_group))

# %% [markdown]
# ## <center>**Congratulations! You have successfully created and visualized graphs in Python.**</center>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <center>**This is the end of the exercise.**</center>
